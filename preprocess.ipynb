# %%
import matplotlib.pyplot as plt

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("paultimothymooney/breast-histopathology-images")

print("Path to dataset files:", path)
# Out:
# Resuming download from 278921216 bytes (3047899608 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/paultimothymooney/breast-histopathology-images?dataset_version_number=1 (278921216/3326820824) bytes left.
# 100%|██████████| 3.10G/3.10G [03:16<00:00, 15.5MB/s]
# Extracting files...
# Path to dataset files: C:\Users\travi\.cache\kagglehub\datasets\paultimothymooney\breast-histopathology-images\versions\1

# %%
sample_image = plt.imread('breast-histopathology-images/versions/1/16554/1/16554_idx5_x201_y551_class1.png')
plt.imshow(sample_image)
